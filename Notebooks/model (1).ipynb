# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model("bus.jpg")

results[0].show()
# Out:
# image 1/1 c:\Users\yuvan\SAFETYEYE\Notebooks\bus.jpg: 640x480 4 persons, 1 bus, 290.8ms
# Speed: 7.7ms preprocess, 290.8ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
