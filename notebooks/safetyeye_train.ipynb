# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Base dataset folder (new drive location)
base_path = "/content/drive/MyDrive/dataset"
os.makedirs(base_path, exist_ok=True)

print("✅ Folder ready at:", base_path)
# Out:
# ✅ Folder ready at: /content/drive/MyDrive/dataset

# %% [markdown]
# !unzip -q /content/drive/MyDrive/processed.zip -d /content/

# %%
from ultralytics import YOLO
import os

# Load YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train on 1000 images dataset
model.train(
    data="/content/drive/MyDrive/dataset_small/data.yaml",  # new dataset
    epochs=25,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.002,               # good default LR for AdamW
    lrf=0.1,
    weight_decay=0.01,       # AdamW benefits from stronger decay
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run",
    exist_ok=True,
    augment=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3909371431.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import os
#       3
#       4 # Load YOLOv8 small model
#       5 model = YOLO("yolov8s.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# Load YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train on 1000 images dataset
model.train(
    data="/content/processed/data.yaml",  # new dataset
    epochs=25,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.002,               # good default LR for AdamW
    lrf=0.1,
    weight_decay=0.01,       # AdamW benefits from stronger decay
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run",
    exist_ok=True,
    augment=True
)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import os

# Load YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train on 1000 images dataset
model.train(
    data="/content/processed/data.yaml",  # new dataset
    epochs=25,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.002,               # good default LR for AdamW
    lrf=0.1,
    weight_decay=0.01,       # AdamW benefits from stronger decay
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run",
    exist_ok=True,
    augment=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3085373041.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import os
#       3
#       4 # Load YOLOv8 small model
#       5 model = YOLO("yolov8s.pt")
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os

# Load YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train on 1000 images dataset
model.train(
    data="/content/processed/data.yaml",  # new dataset
    epochs=40,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.005,               # good default LR for AdamW
    lrf=0.1,
    weight_decay=0.01,       # AdamW benefits from stronger decay
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_1",
    exist_ok=True,
    augment=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1615051293.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import os
#       3
#       4 # Load YOLOv8 small model
#       5 model = YOLO("yolov8s.pt")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/__init__.py in <module>
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
#      10
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, YOLOE, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/__init__.py in <module>
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#       2
# ----> 3 from .fastsam import FastSAM
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio ultralytics
# Out:
# Found existing installation: torch 2.8.0+cu126
# Uninstalling torch-2.8.0+cu126:
#   Successfully uninstalled torch-2.8.0+cu126
# Found existing installation: torchvision 0.23.0+cu126
# Uninstalling torchvision-0.23.0+cu126:
#   Successfully uninstalled torchvision-0.23.0+cu126
# Found existing installation: torchaudio 2.8.0+cu126
# Uninstalling torchaudio-2.8.0+cu126:
#   Successfully uninstalled torchaudio-2.8.0+cu126
# Found existing installation: ultralytics 8.3.198
# Uninstalling ultralytics-8.3.198:
#   Successfully uninstalled ultralytics-8.3.198

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 65.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#   Using cached ultralytics-8.3.198-py3-none-any.whl.metadata (37 kB)
# ...
# Using cached ultralytics-8.3.198-py3-none-any.whl (1.1 MB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=40,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.005,
    lrf=0.1,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_1",
    exist_ok=True,
    augment=True
)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cpu CPU (Intel Xeon CPU @ 2.00GHz)
# ...

# %%
# !unzip -q /content/drive/MyDrive/processed.zip -d /content/

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=40,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.005,
    lrf=0.1,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_1",
    exist_ok=True,
    augment=True
)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cpu CPU (Intel Xeon CPU @ 2.00GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=40,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.005,
    lrf=0.1,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_1",
    exist_ok=True,
    augment=True
)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cpu CPU (Intel Xeon CPU @ 2.00GHz)
# ...

# %%
# !unzip -q /content/drive/MyDrive/dataset.zip -d /content/

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/dataset/data.yaml",
    epochs=40,
    imgsz=640,
    batch=32,
    optimizer="AdamW",
    lr0=0.005,
    lrf=0.1,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_1",
    exist_ok=True,
    augment=True
)
# Out:
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cpu CPU (Intel Xeon CPU @ 2.00GHz)
# ...

# %%
# !rm -rf /content/dataset

# %%
# !unzip -q /content/drive/MyDrive/processed.zip -d /content/

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=40,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.002,
    lrf=0.1,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_2",
    exist_ok=True,
    augment=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.198 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !unzip -q /content/drive/MyDrive/processed.zip -d /content/

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=50,
    patience=5,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.001,
    lrf=0.005,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_3",
    exist_ok=True,
    augment=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2365848927.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8s.pt")
#       4
#       5 model.train(
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/processed/data.yaml",
    epochs=50,
    patience=5,
    imgsz=640,
    batch=16,
    optimizer="AdamW",
    lr0=0.001,
    lrf=0.005,
    weight_decay=0.01,
    workers=4,
    project="/content/drive/MyDrive/YOLOv8_training",
    name="ppe_yolov8_small_run_3",
    exist_ok=True,
    augment=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
import os
import argparse
import tkinter as tk
from tkinter import filedialog
from google.colab.patches import cv2_imshow # Use this for displaying images in Colab
from google.colab import drive

# ---------------------------
# Mount Google Drive
# ---------------------------
drive.mount('/content/drive')

# ---------------------------
# 1. Load YOLOv8 model
# ---------------------------
# Update the path to point to your Google Drive location
model_path = "/content/drive/MyDrive/YOLOv8_training/ppe_yolov8_small_run_3/weights/best.pt"
model = YOLO(model_path)

# ---------------------------
# 2. Process frame (common for photo, video, webcam)
# ---------------------------
def process_frame(frame):
    # Use conf=0.5 as a starting point. Adjust based on your F1-Confidence curve.
    results = model(frame, conf=0.5)

    # Check for violations
    is_violation = False
    for r in results:
        boxes = r.boxes
        for box in boxes:
            cls = int(box.cls[0])
            name = model.names[cls]
            if name in ['NO-Hardhat', 'NO-Safety Vest', 'NO-Mask']:
                is_violation = True
                print(f"🚨 Violation Detected: {name} at confidence {box.conf[0]:.2f}")
                # You can add your email alert logic here

    # Annotate frame
    annotated_frame = results[0].plot()

    return annotated_frame, is_violation

# ---------------------------
# 3. Main function with mode selection
# ---------------------------
def main(mode, source=None):
    # In Colab, we can't use tkinter's filedialog.
    # The source must be a direct path.

    if mode == "photo":
        if not source:
            print("❌ Please provide a direct path to the photo.")
            return

        frame = cv2.imread(source)
        if frame is None:
            print("❌ Could not read the photo!")
            return

        annotated_frame, _ = process_frame(frame)
        cv2_imshow(annotated_frame) # Use cv2_imshow for Colab

    elif mode == "video":
        if not source:
            print("❌ Please provide a direct path to the video.")
            return

        cap = cv2.VideoCapture(source)
        if not cap.isOpened():
            print("❌ Could not open video!")
            return

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            annotated_frame, is_violation = process_frame(frame)
            cv2_imshow(annotated_frame)

            # This is not a real-time keystroke check in Colab
            # so you'll have to interrupt the cell to stop

        cap.release()

    elif mode == "webcam":
        print("💡 Setting up webcam. Please grant permission when prompted.")
        # This part requires a specific Colab library for webcam access.
        # It's a bit more complex than simple CV2.
        print("This feature is not directly supported by this script in Colab.")
        print("You would need to use `from google.colab.patches import cv2_imshow` and a specific method to capture webcam feed.")

    else:
        print("❌ Invalid mode! Choose 'photo' or 'video'.")

# ---------------------------
# 4. CLI argument parsing
# ---------------------------
if __name__ == "__main__":
    # In Colab, you can't use argparse directly like in a local terminal.
    # You would define mode and source manually.

    # Example usage:
    # Set mode and source to a video file in your drive
    # main(mode="video", source="/content/drive/MyDrive/path/to/your/video.mp4")
    # or for a photo
    # main(mode="photo", source="/content/drive/MyDrive/path/to/your/photo.jpg")

    # For now, let's set a simple example
    # Replace these with your actual paths
    mode_to_run = "photo" # or "video"
    source_path = "/content/drive/MyDrive/YOLOv8_training/test1.jpg"

    main(mode=mode_to_run, source=source_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1527148667.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       3 import os
#       4 import argparse
#       5 import tkinter as tk
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import os
import argparse
import tkinter as tk
from tkinter import filedialog
from google.colab.patches import cv2_imshow # Use this for displaying images in Colab
from google.colab import drive

# ---------------------------
# Mount Google Drive
# ---------------------------
drive.mount('/content/drive')

# ---------------------------
# 1. Load YOLOv8 model
# ---------------------------
# Update the path to point to your Google Drive location
model_path = "/content/drive/MyDrive/YOLOv8_training/ppe_yolov8_small_run_3/weights/best.pt"
model = YOLO(model_path)

# ---------------------------
# 2. Process frame (common for photo, video, webcam)
# ---------------------------
def process_frame(frame):
    # Use conf=0.5 as a starting point. Adjust based on your F1-Confidence curve.
    results = model(frame, conf=0.5)

    # Check for violations
    is_violation = False
    for r in results:
        boxes = r.boxes
        for box in boxes:
            cls = int(box.cls[0])
            name = model.names[cls]
            if name in ['NO-Hardhat', 'NO-Safety Vest', 'NO-Mask']:
                is_violation = True
                print(f"🚨 Violation Detected: {name} at confidence {box.conf[0]:.2f}")
                # You can add your email alert logic here

    # Annotate frame
    annotated_frame = results[0].plot()

    return annotated_frame, is_violation

# ---------------------------
# 3. Main function with mode selection
# ---------------------------
def main(mode, source=None):
    # In Colab, we can't use tkinter's filedialog.
    # The source must be a direct path.

    if mode == "photo":
        if not source:
            print("❌ Please provide a direct path to the photo.")
            return

        frame = cv2.imread(source)
        if frame is None:
            print("❌ Could not read the photo!")
            return

        annotated_frame, _ = process_frame(frame)
        cv2_imshow(annotated_frame) # Use cv2_imshow for Colab

    elif mode == "video":
        if not source:
            print("❌ Please provide a direct path to the video.")
            return

        cap = cv2.VideoCapture(source)
        if not cap.isOpened():
            print("❌ Could not open video!")
            return

        while True:
            ret, frame = cap.read()
            if not ret:
                break

            annotated_frame, is_violation = process_frame(frame)
            cv2_imshow(annotated_frame)

            # This is not a real-time keystroke check in Colab
            # so you'll have to interrupt the cell to stop

        cap.release()

    elif mode == "webcam":
        print("💡 Setting up webcam. Please grant permission when prompted.")
        # This part requires a specific Colab library for webcam access.
        # It's a bit more complex than simple CV2.
        print("This feature is not directly supported by this script in Colab.")
        print("You would need to use `from google.colab.patches import cv2_imshow` and a specific method to capture webcam feed.")

    else:
        print("❌ Invalid mode! Choose 'photo' or 'video'.")

# ---------------------------
# 4. CLI argument parsing
# ---------------------------
if __name__ == "__main__":
    # In Colab, you can't use argparse directly like in a local terminal.
    # You would define mode and source manually.

    # Example usage:
    # Set mode and source to a video file in your drive
    # main(mode="video", source="/content/drive/MyDrive/path/to/your/video.mp4")
    # or for a photo
    # main(mode="photo", source="/content/drive/MyDrive/path/to/your/photo.jpg")

    # For now, let's set a simple example
    # Replace these with your actual paths
    mode_to_run = "photo" # or "video"
    source_path = "/content/drive/MyDrive/YOLOv8_training/test1.jpg"

    main(mode=mode_to_run, source=source_path)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 0: 480x640 4 Hardhats, 4 NO-Masks, 5 Persons, 4 Safety Vests, 45.0ms
# Speed: 16.2ms preprocess, 45.0ms inference, 358.1ms postprocess per image at shape (1, 3, 480, 640)
# 🚨 Violation Detected: NO-Mask at confidence 0.78
# 🚨 Violation Detected: NO-Mask at confidence 0.69
# 🚨 Violation Detected: NO-Mask at confidence 0.63
# 🚨 Violation Detected: NO-Mask at confidence 0.62
# <PIL.Image.Image image mode=RGB size=1300x956>
